# %% [markdown]
# # Deeper Dive on Process Analysis

# %% [markdown]
# COMMENT: there are no conclusions specified. I was spending time on running commands properly and understanding outputs, trying to figure out connections between processes, timelines. Time was also spent on researching different processes like alg.exe.
#
# The most suspicious activity was the launch of alg.exe on 2009-04-16 16:10:21 followed by a Windows installer msiexec.exe on 2009-04-16 16:11:02 which I think installed a trojan.  When Mandiant's tool was installed a month later, Internet Explorer also got launched, connecting automatically to some Chinese ip addresses.
#
# Of course, this is the absolute beginner's take on this image analysis.

# %% [markdown]
# ## PSLIST

# %%
python.exe C:\Users\Z\Anaconda2\volatility\vol.py -f C:\Users\Z\Documents\GitHub\ir1\IncidentResponse\processanalysis\APT.img --profile=WinXPSP2x86 pslist
# Out:
# Volatility Foundation Volatility Framework 2.6
# *** Failed to import volatility.plugins.malware.apihooks (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.malware.threads (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks_kernel (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.mac.check_syscall_shadow (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.ssdt (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks (ImportError: No module named distorm3)
# Offset(V)  Name                    PID   PPID   Thds     Hnds   Sess  Wow64 Start                          Exit
# ---------- -------------------- ------ ------ ------ -------- ------ ------ ------------------------------ ------------------------------
# 0x823c8830 System                    4      0     55      254 ------      0
# ...

# %% [markdown]
# ## PSTREE

# %%
python.exe C:\Users\Z\Anaconda2\volatility\vol.py -f C:\Users\Z\Documents\GitHub\ir1\IncidentResponse\processanalysis\APT.img --profile=WinXPSP2x86 pstree
# Out:
# Volatility Foundation Volatility Framework 2.6
# *** Failed to import volatility.plugins.malware.apihooks (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.malware.threads (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks_kernel (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.mac.check_syscall_shadow (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.ssdt (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks (ImportError: No module named distorm3)
# Name                                                  Pid   PPid   Thds   Hnds Time
# -------------------------------------------------- ------ ------ ------ ------ ----
#  0x823c8830:System                                      4      0     55    254 1970-01-01 00:00:00 UTC+0000
# ...

# %% [markdown]
# ## PSSCAN

# %%
python.exe C:\Users\Z\Anaconda2\volatility\vol.py -f C:\Users\Z\Documents\GitHub\ir1\IncidentResponse\processanalysis\APT.img --profile=WinXPSP2x86 psscan
# Out:
# Volatility Foundation Volatility Framework 2.6
# *** Failed to import volatility.plugins.malware.apihooks (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.malware.threads (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks_kernel (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.mac.check_syscall_shadow (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.ssdt (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks (ImportError: No module named distorm3)
# Offset(P)          Name                PID   PPID PDB        Time created                   Time exited
# ------------------ ---------------- ------ ------ ---------- ------------------------------ ------------------------------
# 0x0000000001f33628 alg.exe             464    704 0x08c002e0 2009-04-16 16:10:21 UTC+0000
# ...

# %% [markdown]
# ## PSXVIEW

# %%
python.exe C:\Users\Z\Anaconda2\volatility\vol.py -f C:\Users\Z\Documents\GitHub\ir1\IncidentResponse\processanalysis\APT.img --profile=WinXPSP2x86 psxview
# Out:
# Volatility Foundation Volatility Framework 2.6
# *** Failed to import volatility.plugins.malware.apihooks (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.malware.threads (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks_kernel (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.mac.check_syscall_shadow (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.ssdt (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks (ImportError: No module named distorm3)
# Offset(P)  Name                    PID pslist psscan thrdproc pspcid csrss session deskthrd ExitTime
# ---------- -------------------- ------ ------ ------ -------- ------ ----- ------- -------- --------
# 0x02163020 winlogon.exe            660 True   True   True     True   True  True    True
# ...

# %% [markdown]
# ## PSTREE GraphViz output

# %%
python.exe C:\Users\Z\Anaconda2\volatility\vol.py -f C:\Users\Z\Documents\GitHub\ir1\IncidentResponse\processanalysis\APT.img --profile=WinXPSP2x86 pstree --output=dot --output-file=process.dot
# Out:
# Volatility Foundation Volatility Framework 2.6
# *** Failed to import volatility.plugins.malware.apihooks (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.malware.threads (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks_kernel (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.mac.check_syscall_shadow (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.ssdt (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks (ImportError: No module named distorm3)
# Outputting to: process.dot

# %% [markdown]
# ### Users
# To analyze users associated with processes you can use the plugin `getsids`, SIDs standing for security identifier. You should see SIDs for local and domain users

# %%
python.exe C:\Users\Z\Anaconda2\volatility\vol.py -f C:\Users\Z\Documents\GitHub\ir1\IncidentResponse\processanalysis\APT.img --profile=WinXPSP2x86 getsids
# Out:
# Volatility Foundation Volatility Framework 2.6
# *** Failed to import volatility.plugins.malware.apihooks (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.malware.threads (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks_kernel (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.mac.check_syscall_shadow (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.ssdt (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks (ImportError: No module named distorm3)
# System (4): S-1-5-18 (Local System)
# System (4): S-1-5-32-544 (Administrators)
# System (4): S-1-1-0 (Everyone)
# System (4): S-1-5-11 (Authenticated Users)
# smss.exe (564): S-1-5-18 (Local System)
# smss.exe (564): S-1-5-32-544 (Administrators)
# smss.exe (564): S-1-1-0 (Everyone)
# smss.exe (564): S-1-5-11 (Authenticated Users)
# ...

# %% [markdown]
# COMMENT:
#
# iexplore.exe (796): S-1-5-18 (Local System)
# iexplore.exe (796): S-1-5-32-544 (Administrators)
# iexplore.exe (796): S-1-1-0 (Everyone)
# iexplore.exe (796): S-1-5-11 (Authenticated Users)

# %% [markdown]
# Reviewing all the SIDs can be daunting so try to focus just on the process we identified as supicoius and parent processes in this case PID (796)
#
# ### Privilleges
#
# You can also see what privilleges are associated with each user if you do not have access to that infomration in other formats (like if you don't have access to the affected domain). You can enumerate privilleges with the privs command as shown below:

# %%
python.exe C:\Users\Z\Anaconda2\volatility\vol.py -f C:\Users\Z\Documents\GitHub\ir1\IncidentResponse\processanalysis\APT.img --profile=WinXPSP2x86 privs
# Out:
# Volatility Foundation Volatility Framework 2.6
# *** Failed to import volatility.plugins.malware.apihooks (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.malware.threads (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks_kernel (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.mac.check_syscall_shadow (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.ssdt (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks (ImportError: No module named distorm3)
# Pid      Process          Value  Privilege                            Attributes               Description
# -------- ---------------- ------ ------------------------------------ ------------------------ -----------
#        4 System                7 SeTcbPrivilege                       Present,Enabled,Default  Act as part of the operating system
# ...

# %% [markdown]
# COMMENT:
#
# 796 iexplore.exe          7 SeTcbPrivilege                       Present,Enabled,Default  Act as part of the operating system
#      796 iexplore.exe          2 SeCreateTokenPrivilege               Present                  Create a token object
#      796 iexplore.exe          9 SeTakeOwnershipPrivilege             Present                  Take ownership of files/objects
#      796 iexplore.exe         15 SeCreatePagefilePrivilege            Present,Enabled,Default  Create a pagefile
#      796 iexplore.exe          4 SeLockMemoryPrivilege                Present,Enabled,Default  Lock pages in memory
#      796 iexplore.exe          3 SeAssignPrimaryTokenPrivilege        Present                  Replace a process-level token
#      796 iexplore.exe          5 SeIncreaseQuotaPrivilege             Present                  Increase quotas
#      796 iexplore.exe         14 SeIncreaseBasePriorityPrivilege      Present,Enabled,Default  Increase scheduling priority
#      796 iexplore.exe         16 SeCreatePermanentPrivilege           Present,Enabled,Default  Create permanent shared objects
#      796 iexplore.exe         20 SeDebugPrivilege                     Present,Enabled,Default  Debug programs
#      796 iexplore.exe         21 SeAuditPrivilege                     Present,Enabled,Default  Generate security audits
#      796 iexplore.exe          8 SeSecurityPrivilege                  Present                  Manage auditing and security log
#      796 iexplore.exe         22 SeSystemEnvironmentPrivilege         Present                  Edit firmware environment values
#      796 iexplore.exe         23 SeChangeNotifyPrivilege              Present,Enabled,Default  Receive notifications of changes to files or directories
#      796 iexplore.exe         17 SeBackupPrivilege                    Present                  Backup files and directories
#      796 iexplore.exe         18 SeRestorePrivilege                   Present                  Restore files and directories
#      796 iexplore.exe         19 SeShutdownPrivilege                  Present                  Shut down the system
#      796 iexplore.exe         10 SeLoadDriverPrivilege                Present                  Load and unload device drivers
#      796 iexplore.exe         13 SeProfileSingleProcessPrivilege      Present,Enabled,Default  Profile a single process
#      796 iexplore.exe         12 SeSystemtimePrivilege                Present                  Change the system time
#      796 iexplore.exe         25 SeUndockPrivilege                    Present                  Remove computer from docking station
#      796 iexplore.exe         28 SeManageVolumePrivilege              Present                  Manage the files on a volume
#      796 iexplore.exe         29 SeImpersonatePrivilege               Present,Enabled,Default  Impersonate a client after authentication
#      796 iexplore.exe         30 SeCreateGlobalPrivilege              Present,Enabled,Default  Create global objects

# %% [markdown]
# ### PE Version Information

# %%
python.exe C:\Users\Z\Anaconda2\volatility\vol.py -f C:\Users\Z\Documents\GitHub\ir1\IncidentResponse\processanalysis\APT.img --profile=WinXPSP2x86 getsids verinfo
# Out:
# Volatility Foundation Volatility Framework 2.6
# *** Failed to import volatility.plugins.malware.apihooks (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.malware.threads (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks_kernel (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.mac.check_syscall_shadow (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.ssdt (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks (ImportError: No module named distorm3)
# System (4): S-1-5-18 (Local System)
# System (4): S-1-5-32-544 (Administrators)
# System (4): S-1-1-0 (Everyone)
# System (4): S-1-5-11 (Authenticated Users)
# smss.exe (564): S-1-5-18 (Local System)
# smss.exe (564): S-1-5-32-544 (Administrators)
# smss.exe (564): S-1-1-0 (Everyone)
# smss.exe (564): S-1-5-11 (Authenticated Users)
# ...

# %% [markdown]
# COMMENT:
#
# iexplore.exe (796): S-1-5-18 (Local System)
# iexplore.exe (796): S-1-5-32-544 (Administrators)
# iexplore.exe (796): S-1-1-0 (Everyone)
# iexplore.exe (796): S-1-5-11 (Authenticated Users)

# %% [markdown]
# ### Loaded DLL's

# %%
python.exe C:\Users\Z\Anaconda2\volatility\vol.py -f C:\Users\Z\Documents\GitHub\ir1\IncidentResponse\processanalysis\APT.img --profile=WinXPSP2x86 dlllist --pid=796
# Out:
# Volatility Foundation Volatility Framework 2.6
# *** Failed to import volatility.plugins.malware.apihooks (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.malware.threads (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks_kernel (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.mac.check_syscall_shadow (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.ssdt (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks (ImportError: No module named distorm3)
# ************************************************************************
# iexplore.exe pid:    796
# Command line : "C:\Program Files\Internet Explorer\iexplore.exe"
# Service Pack 3
#
# Base             Size  LoadCount LoadTime                       Path
# ---------- ---------- ---------- ------------------------------ ----
# ...

# %%
python.exe C:\Users\Z\Anaconda2\volatility\vol.py -f C:\Users\Z\Documents\GitHub\ir1\IncidentResponse\processanalysis\APT.img --profile=WinXPSP2x86 handles --pid=796
# Out:
# Volatility Foundation Volatility Framework 2.6
# *** Failed to import volatility.plugins.malware.apihooks (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.malware.threads (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks_kernel (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.mac.check_syscall_shadow (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.ssdt (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks (ImportError: No module named distorm3)
# Offset(V)     Pid     Handle     Access Type             Details
# ---------- ------ ---------- ---------- ---------------- -------
# 0x821ace98    796        0xc   0x100020 File             \Device\HarddiskVolume1\WINDOWS\system32
# 0x82189028    796      0x578   0x12019f File             \Device\NamedPipe\ROUTER
# ...

# %% [markdown]
# You can also limit what handles are enumerated by using the `-t ObjectType` as shown below:

# %%
python.exe C:\Users\Z\Anaconda2\volatility\vol.py -f C:\Users\Z\Documents\GitHub\ir1\IncidentResponse\processanalysis\APT.img --profile=WinXPSP2x86 handles --pid=1464 -t File,Key
# Out:
# Volatility Foundation Volatility Framework 2.6
# *** Failed to import volatility.plugins.malware.apihooks (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.malware.threads (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks_kernel (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.mac.check_syscall_shadow (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.ssdt (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks (ImportError: No module named distorm3)
# Offset(V)     Pid     Handle     Access Type             Details
# ---------- ------ ---------- ---------- ---------------- -------
# 0x822f7cc8   1464        0xc   0x100020 File             \Device\HarddiskVolume1\WINDOWS\system32
# 0xe11a4460   1464       0x28  0x20f003f Key              MACHINE
# ...

# %% [markdown]
# ## Command Line History
# ### cmdscan
# You can see the command line history by enumerating COMMAND_HISTORY objects from memory. There are different plugins that can parse these data points. This enumeration works by looking for a known constant called `(MaxHistory)` which is a parameter that stores the max number of commands to keep in a buffer. These structures are stored in `csrss.exe` in XP/2003/Vista/2008 and `conhost.exe` in Windows 7. The plugin to review this data on XP systems is below.

# %%
python.exe C:\Users\Z\Anaconda2\volatility\vol.py -f C:\Users\Z\Documents\GitHub\ir1\IncidentResponse\processanalysis\APT.img --profile=WinXPSP2x86 cmdscan
# Out:
# Volatility Foundation Volatility Framework 2.6
# *** Failed to import volatility.plugins.malware.apihooks (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.malware.threads (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks_kernel (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.mac.check_syscall_shadow (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.ssdt (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks (ImportError: No module named distorm3)
# **************************************************
# CommandProcess: csrss.exe Pid: 636
# CommandHistory: 0x1007910 Application: MIRAgent.exe Flags: Allocated
# CommandCount: 0 LastAdded: -1 LastDisplayed: -1
# FirstCommand: 0 CommandCountMax: 50
# ProcessHandle: 0x104
# **************************************************
# ...

# %% [markdown]
# ### consoles
# You can also find more command line parameter data by parsing the `CONSOLE_INFORMATION` objects in memory. These objects not only show the command being executed but also the output buffer from the command. This command can be useful espeically if you are looking for attackers exiltrating data, users and passwords being used, archive file passwords, or if their malware has command parameters which are required to be provided when ran. The plugin to view this data is below:

# %%
python.exe C:\Users\Z\Anaconda2\volatility\vol.py -f C:\Users\Z\Documents\GitHub\ir1\IncidentResponse\processanalysis\APT.img --profile=WinXPSP2x86 consoles
# Out:
# Volatility Foundation Volatility Framework 2.6
# *** Failed to import volatility.plugins.malware.apihooks (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.malware.threads (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks_kernel (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.mac.check_syscall_shadow (ImportError: No module named distorm3)
# *** Failed to import volatility.plugins.ssdt (NameError: name 'distorm3' is not defined)
# *** Failed to import volatility.plugins.mac.apihooks (ImportError: No module named distorm3)
# **************************************************
# ConsoleProcess: csrss.exe Pid: 636
# Console: 0x4f2378 CommandHistorySize: 50
# HistoryBufferCount: 2 HistoryBufferMax: 4
# OriginalTitle: %SystemRoot%\system32\cmd.exe
# Title: C:\WINDOWS\system32\cmd.exe - MIRAgent.exe -o -script MalwareAudit.Batch.xml -encoding none
# ...
